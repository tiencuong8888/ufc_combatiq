# %%
import pickle
from combat_iq.ml_logic.data import *
from combat_iq.ml_logic.preprocessors import *

# %%
df = get_data()

# %%
df.head()
# Out:
#    Unnamed: 0            fighter        date  avg_KD  avg_opp_KD  \
# 0           0      Gustavo Lopez  2021-03-20   0.000         0.0
# 1           1      Roman Dolidze  2021-03-20   0.500         0.0
# 2           2    Harry Hunsucker  2021-03-20     NaN         NaN
# 3           3  Montserrat Conejo  2021-03-20     NaN         NaN
# 4           4      Macy Chiasson  2021-03-20   0.125         0.0
#
#    avg_SIG_STR_pct  avg_opp_SIG_STR_pct  avg_TD_pct  avg_opp_TD_pct  \
# 0         0.420000              0.49500       0.330         0.36000
# 1         0.660000              0.30500       0.300         0.50000
# 2              NaN                  NaN         NaN             NaN
# 3              NaN                  NaN         NaN             NaN
# 4         0.535625              0.57875       0.185         0.16625
#
#    avg_SUATT  ...  avg_SUB_ATT  avg_opp_SUB_ATT  avg_SIG_STatt  \
# 0      0.500  ...          NaN              NaN            NaN
# ...

# %%
fight_data = preprocessed_df("Harry Hunsucker", "Roman Dolidze")

# %%
    with open('models/simple_model.pkl', 'rb') as file:
        model = pickle.load(file)
# Out:
# /Users/clementguinel/.pyenv/versions/3.10.6/envs/ufc_combatiq/lib/python3.10/site-packages/sklearn/base.py:348: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.4.1.post1 when using version 1.3.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
model
# Out:
# LogisticRegression(max_iter=10000)

# %%
model.predict_proba(fight_data)[0][2]
# Out:
# 0.7233682101248835

# %%
model.predict(fight_data)
# Out:
# array(['Red'], dtype=object)

# %%
model.classes_
# Out:
# array(['Blue', 'Draw', 'Red'], dtype=object)

# %%
f'{model.predict_proba(fight_data)[0][0] * 100:.1f} %'
# Out:
# '25.9 %'

# %%
all_fighters = get_data()

# %%
all_fighters.head()
# Out:
#    Unnamed: 0            fighter        date  avg_KD  avg_opp_KD  \
# 0           0      Gustavo Lopez  2021-03-20   0.000         0.0
# 1           1      Roman Dolidze  2021-03-20   0.500         0.0
# 2           2    Harry Hunsucker  2021-03-20     NaN         NaN
# 3           3  Montserrat Conejo  2021-03-20     NaN         NaN
# 4           4      Macy Chiasson  2021-03-20   0.125         0.0
#
#    avg_SIG_STR_pct  avg_opp_SIG_STR_pct  avg_TD_pct  avg_opp_TD_pct  \
# 0         0.420000              0.49500       0.330         0.36000
# 1         0.660000              0.30500       0.300         0.50000
# 2              NaN                  NaN         NaN             NaN
# 3              NaN                  NaN         NaN             NaN
# 4         0.535625              0.57875       0.185         0.16625
#
#    avg_SUATT  ...  avg_SUB_ATT  avg_opp_SUB_ATT  avg_SIG_STatt  \
# 0      0.500  ...          NaN              NaN            NaN
# ...

# %%
list = all_fighters.fighter.tolist()

# %%
all_fighters[all_fighters.fighter.str.contains('Conor')]
# Out:
#     Unnamed: 0         fighter        date    avg_KD  avg_opp_KD  \
# 85          85  Conor McGregor  2021-01-23  1.093262         0.0
#
#     avg_SIG_STR_pct  avg_opp_SIG_STR_pct  avg_TD_pct  avg_opp_TD_pct  \
# 85         0.636924             0.229868    0.001367        0.149453
#
#     avg_SUATT  ...  avg_SUB_ATT  avg_opp_SUB_ATT  avg_SIG_STatt  \
# 85        0.0  ...          NaN              NaN            NaN
#
#     avg_SIG_STlanded  avg_opp_SIG_STatt  avg_opp_SIG_STlanded  \
# 85               NaN                NaN                   NaN
#
#     avg_TOTAL_STatt  avg_TOTAL_STlanded  avg_opp_TOTAL_STatt  \
# 85              NaN                 NaN                  NaN
#
#     avg_opp_TOTAL_STlanded
# 85                     NaN
#
# [1 rows x 83 columns]
